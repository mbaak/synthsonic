# %%
# %load_ext autoreload
# %autoreload 2

# %%
from timeit import default_timer as timer
from functools import partial
from random import choices
import logging

# %%
import sdgym
from sdgym import load_dataset
from sdgym import benchmark
from sdgym import load_dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

# %%
import pgmpy

from pgmpy.models import BayesianModel
from pgmpy.estimators import TreeSearch, HillClimbSearch, BicScore, ExhaustiveSearch, BayesianEstimator
from pgmpy.sampling import BayesianModelSampling

# %%
import xgboost as xgb
from xgboost import XGBClassifier

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.isotonic import IsotonicRegression

# %%
from scipy import interpolate

# %%
from synthsonic.models.kde_utils import kde_smooth_peaks_1dim, kde_smooth_peaks
from synthsonic.models.kde_copula_nn_pdf import KDECopulaNNPdf

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
logging.basicConfig(level=logging.INFO)

# %%
#dataset_name = 'intrusion_numeric_u100'
#dataset_name = 'intrusion_categorical'
#dataset_name = 'intrusion_u100'
dataset_name = 'intrusion'

# %%
data, categorical_columns, ordinal_columns = load_dataset(dataset_name)
# Out:
# INFO:sdgym.data:Loading dataset intrusion (all variables, -1 distinct values threshold)
# INFO:sdgym.data:Columns to zero-code: []

# %%
data.shape
# Out:
# (394021, 41)

# %%
#clf = lgb.LGBMClassifier() #**param)
#clffitkw = {'categorical_feature': categorical_columns+ordinal_columns}

# %% [markdown]
# # run sdgym

# %%
def KDECopulaNNPdf_Synthesizer(real_data, categorical_columns, ordinal_columns):
    # assert len(categorical_columns + ordinal_columns) <= 1

    all_features = list(range(real_data.shape[1]))
    numerical_features = list(set(all_features) - set(categorical_columns + ordinal_columns))
    data = np.float64(real_data)
    
    n_samples = data.shape[0]
    n_features = data.shape[1]
    
    clf = xgb.XGBClassifier(
        n_estimators=250,
        reg_lambda=1,
        gamma=0,
        max_depth=9
    )
#     clf = MLPClassifier(alpha=0.1, random_state=0, max_iter=1000, early_stopping=True)
    
    kde = KDECopulaNNPdf(
        use_KDE=False, 
        categorical_columns=categorical_columns+ordinal_columns,
        distinct_threshold=-1,
        n_bins=25,
#        clf=clf,
#         ordering='mi',
    )
    kde = kde.fit(data)
    
#     X_gen, sample_weight = kde.sample(n_samples)
    X_gen = kde.sample_no_weights(n_samples, show_progress=True, mode='cheap')
    
    #X_gen[:, categorical_columns+ordinal_columns] = np.round(X_gen[:, categorical_columns+ordinal_columns])
    X_gen = np.float32(X_gen)
    
    print(X_gen[:, :5])

    return X_gen

# %%
def KDECopulaNNPdf_SynthesizerInteger(real_data, categorical_columns, ordinal_columns):
    """Census has integer only..."""
    data = KDECopulaNNPdf_Synthesizer(real_data, categorical_columns, ordinal_columns)
    data = np.round(data)
    
    print(data[:, :5])

    return data

# %%
from sdgym.synthesizers import (
    CLBNSynthesizer, CTGANSynthesizer, IdentitySynthesizer, IndependentSynthesizer,
    MedganSynthesizer, PrivBNSynthesizer, TableganSynthesizer, TVAESynthesizer,
    UniformSynthesizer, VEEGANSynthesizer, CopulaGAN)

all_synthesizers = [
#    IdentitySynthesizer,
#     IndependentSynthesizer,
#     KDECopulaNNPdf_Synthesizer,
#    CopulaGAN
     KDECopulaNNPdf_SynthesizerInteger,
]

# %%
scores = sdgym.run(synthesizers=all_synthesizers, datasets=[dataset_name], iterations=1)
# Out:
# INFO:sdgym.benchmark:0%|          | 0/1 [00:00<?, ?it/s]
# INFO:sdgym.benchmark:Evaluating KDECopulaNNPdf_SynthesizerInteger on dataset intrusion; iteration 0; 436.74 MB
# INFO:sdgym.data:Loading dataset intrusion (all variables, -1 distinct values threshold)
# INFO:sdgym.data:Columns to zero-code: []
# INFO:sdgym.benchmark:Running KDECopulaNNPdf_SynthesizerInteger on dataset intrusion; iteration 0; 518.58 MB
# INFO:KDECopulaNNPdf:Processing 26 numerical and 15 categorical columns
# INFO:KDECopulaNNPdf:Transforming numerical variables.
# INFO:KDECopulaNNPdf:Configuring Bayesian Network (cat+num).
# INFO:KDECopulaNNPdf:Configuring classifier.
# INFO:KDECopulaNNPdf:Generating 394021 data points.
#
#   0%|          | 0/41 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/41 [00:00<?, ?it/s]
# Generating for node: 0:   0%|          | 0/41 [00:00<?, ?it/s]
# Generating for node: 0:   5%|▍         | 2/41 [00:00<00:05,  7.72it/s]
# Generating for node: 7:   5%|▍         | 2/41 [00:00<00:05,  7.72it/s]
# Generating for node: 7:   7%|▋         | 3/41 [00:00<00:09,  3.92it/s]
# Generating for node: 35:   7%|▋         | 3/41 [00:00<00:09,  3.92it/s]
# Generating for node: 35:  10%|▉         | 4/41 [00:01<00:11,  3.20it/s]
# Generating for node: 39:  10%|▉         | 4/41 [00:01<00:11,  3.20it/s]
# Generating for node: 39:  12%|█▏        | 5/41 [00:01<00:13,  2.62it/s]
# Generating for node: 3:  12%|█▏        | 5/41 [00:01<00:13,  2.62it/s]
# Generating for node: 3:  15%|█▍        | 6/41 [00:02<00:14,  2.50it/s]
# Generating for node: 31:  15%|█▍        | 6/41 [00:02<00:14,  2.50it/s]
# Generating for node: 31:  17%|█▋        | 7/41 [00:02<00:13,  2.46it/s]
# Generating for node: 30:  17%|█▋        | 7/41 [00:02<00:13,  2.46it/s]
# Generating for node: 30:  20%|█▉        | 8/41 [00:02<00:12,  2.60it/s]
# Generating for node: 33:  20%|█▉        | 8/41 [00:02<00:12,  2.60it/s]
# Generating for node: 33:  22%|██▏       | 9/41 [00:03<00:12,  2.62it/s]
# Generating for node: 32:  22%|██▏       | 9/41 [00:03<00:12,  2.62it/s]
# Generating for node: 32:  24%|██▍       | 10/41 [00:03<00:11,  2.61it/s]
# Generating for node: 5:  24%|██▍       | 10/41 [00:03<00:11,  2.61it/s]
# Generating for node: 5:  27%|██▋       | 11/41 [00:03<00:11,  2.66it/s]
# Generating for node: 25:  27%|██▋       | 11/41 [00:03<00:11,  2.66it/s]
# Generating for node: 25:  29%|██▉       | 12/41 [00:04<00:11,  2.42it/s]
# Generating for node: 28:  29%|██▉       | 12/41 [00:04<00:11,  2.42it/s]
# Generating for node: 28:  32%|███▏      | 13/41 [00:04<00:11,  2.35it/s]
# Generating for node: 26:  32%|███▏      | 13/41 [00:04<00:11,  2.35it/s]
# Generating for node: 26:  34%|███▍      | 14/41 [00:05<00:11,  2.28it/s]
# Generating for node: 2:  34%|███▍      | 14/41 [00:05<00:11,  2.28it/s]
# Generating for node: 2:  37%|███▋      | 15/41 [00:05<00:11,  2.23it/s]
# Generating for node: 8:  37%|███▋      | 15/41 [00:05<00:11,  2.23it/s]/Users/maxbaak/Projects/pgmpy/pgmpy/factors/discrete/DiscreteFactor.py:517: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   warn(
#
# Generating for node: 8:  39%|███▉      | 16/41 [00:06<00:10,  2.37it/s]
# Generating for node: 14:  39%|███▉      | 16/41 [00:06<00:10,  2.37it/s]
# Generating for node: 14:  41%|████▏     | 17/41 [00:06<00:09,  2.53it/s]
# Generating for node: 6:  41%|████▏     | 17/41 [00:06<00:09,  2.53it/s]
# Generating for node: 6:  44%|████▍     | 18/41 [00:06<00:08,  2.66it/s]
# Generating for node: 17:  44%|████▍     | 18/41 [00:06<00:08,  2.66it/s]
# Generating for node: 17:  46%|████▋     | 19/41 [00:07<00:08,  2.73it/s]
# Generating for node: 10:  46%|████▋     | 19/41 [00:07<00:08,  2.73it/s]
# Generating for node: 10:  49%|████▉     | 20/41 [00:07<00:07,  2.79it/s]
# Generating for node: 18:  49%|████▉     | 20/41 [00:07<00:07,  2.79it/s]
# Generating for node: 18:  51%|█████     | 21/41 [00:07<00:07,  2.81it/s]
# Generating for node: 16:  51%|█████     | 21/41 [00:07<00:07,  2.81it/s]
# Generating for node: 16:  54%|█████▎    | 22/41 [00:08<00:06,  2.72it/s]
# Generating for node: 15:  54%|█████▎    | 22/41 [00:08<00:06,  2.72it/s]
# Generating for node: 15:  56%|█████▌    | 23/41 [00:08<00:06,  2.58it/s]
# Generating for node: 22:  56%|█████▌    | 23/41 [00:08<00:06,  2.58it/s]
# Generating for node: 22:  59%|█████▊    | 24/41 [00:09<00:06,  2.56it/s]
# Generating for node: 21:  59%|█████▊    | 24/41 [00:09<00:06,  2.56it/s]
# Generating for node: 21:  61%|██████    | 25/41 [00:09<00:06,  2.59it/s]
# Generating for node: 20:  61%|██████    | 25/41 [00:09<00:06,  2.59it/s]
# Generating for node: 20:  63%|██████▎   | 26/41 [00:09<00:05,  2.63it/s]
# Generating for node: 9:  63%|██████▎   | 26/41 [00:09<00:05,  2.63it/s]
# Generating for node: 9:  66%|██████▌   | 27/41 [00:10<00:05,  2.65it/s]
# Generating for node: 23:  66%|██████▌   | 27/41 [00:10<00:05,  2.65it/s]
# Generating for node: 23:  68%|██████▊   | 28/41 [00:10<00:04,  2.65it/s]
# Generating for node: 34:  68%|██████▊   | 28/41 [00:10<00:04,  2.65it/s]
# Generating for node: 34:  71%|███████   | 29/41 [00:10<00:04,  2.63it/s]
# Generating for node: 12:  71%|███████   | 29/41 [00:10<00:04,  2.63it/s]
# Generating for node: 12:  73%|███████▎  | 30/41 [00:11<00:04,  2.67it/s]
# Generating for node: 27:  73%|███████▎  | 30/41 [00:11<00:04,  2.67it/s]
# Generating for node: 27:  76%|███████▌  | 31/41 [00:11<00:03,  2.64it/s]
# Generating for node: 38:  76%|███████▌  | 31/41 [00:11<00:03,  2.64it/s]
# Generating for node: 38:  78%|███████▊  | 32/41 [00:12<00:03,  2.67it/s]
# Generating for node: 36:  78%|███████▊  | 32/41 [00:12<00:03,  2.67it/s]
# Generating for node: 36:  80%|████████  | 33/41 [00:12<00:03,  2.56it/s]
# Generating for node: 37:  80%|████████  | 33/41 [00:12<00:03,  2.56it/s]
# Generating for node: 37:  83%|████████▎ | 34/41 [00:12<00:02,  2.40it/s]
# Generating for node: 11:  83%|████████▎ | 34/41 [00:13<00:02,  2.40it/s]
# Generating for node: 11:  85%|████████▌ | 35/41 [00:13<00:02,  2.55it/s]
# Generating for node: 19:  85%|████████▌ | 35/41 [00:13<00:02,  2.55it/s]
# Generating for node: 19:  88%|████████▊ | 36/41 [00:13<00:01,  2.70it/s]
# Generating for node: 4:  88%|████████▊ | 36/41 [00:13<00:01,  2.70it/s]
# Generating for node: 4:  90%|█████████ | 37/41 [00:14<00:01,  2.55it/s]
# Generating for node: 29:  90%|█████████ | 37/41 [00:14<00:01,  2.55it/s]
# Generating for node: 29:  93%|█████████▎| 38/41 [00:14<00:01,  2.35it/s]
# Generating for node: 24:  93%|█████████▎| 38/41 [00:14<00:01,  2.35it/s]
# Generating for node: 24:  95%|█████████▌| 39/41 [00:15<00:00,  2.29it/s]
# Generating for node: 40:  95%|█████████▌| 39/41 [00:15<00:00,  2.29it/s]
# Generating for node: 40:  98%|█████████▊| 40/41 [00:15<00:00,  2.31it/s]
# Generating for node: 13:  98%|█████████▊| 40/41 [00:15<00:00,  2.31it/s]
# Generating for node: 13: 100%|██████████| 41/41 [00:15<00:00,  2.60it/s]
# INFO:KDECopulaNNPdf:Fitting discriminative learner: selected 41 features.
# INFO:KDECopulaNNPdf:Calibrating classifier.
# INFO:KDECopulaNNPdf:Maximum weight found: 766.2390359903051
# INFO:KDECopulaNNPdf:Generating 394021 data points.
#
#   0%|          | 0/41 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/41 [00:00<?, ?it/s]
# Generating for node: 0:   0%|          | 0/41 [00:00<?, ?it/s]
# Generating for node: 0:   5%|▍         | 2/41 [00:00<00:05,  7.77it/s]
# Generating for node: 7:   5%|▍         | 2/41 [00:00<00:05,  7.77it/s]
# Generating for node: 7:   7%|▋         | 3/41 [00:00<00:08,  4.52it/s]
# Generating for node: 35:   7%|▋         | 3/41 [00:00<00:08,  4.52it/s]
# Generating for node: 35:  10%|▉         | 4/41 [00:00<00:10,  3.66it/s]
# Generating for node: 39:  10%|▉         | 4/41 [00:00<00:10,  3.66it/s]
# Generating for node: 39:  12%|█▏        | 5/41 [00:01<00:10,  3.29it/s]
# Generating for node: 3:  12%|█▏        | 5/41 [00:01<00:10,  3.29it/s]
# Generating for node: 3:  15%|█▍        | 6/41 [00:01<00:11,  3.17it/s]
# Generating for node: 31:  15%|█▍        | 6/41 [00:01<00:11,  3.17it/s]
# Generating for node: 31:  17%|█▋        | 7/41 [00:01<00:10,  3.23it/s]
# Generating for node: 30:  17%|█▋        | 7/41 [00:01<00:10,  3.23it/s]
# Generating for node: 30:  20%|█▉        | 8/41 [00:02<00:10,  3.30it/s]
# Generating for node: 33:  20%|█▉        | 8/41 [00:02<00:10,  3.30it/s]
# Generating for node: 33:  22%|██▏       | 9/41 [00:02<00:09,  3.34it/s]
# Generating for node: 32:  22%|██▏       | 9/41 [00:02<00:09,  3.34it/s]
# Generating for node: 32:  24%|██▍       | 10/41 [00:02<00:09,  3.40it/s]
# Generating for node: 5:  24%|██▍       | 10/41 [00:02<00:09,  3.40it/s]
# Generating for node: 5:  27%|██▋       | 11/41 [00:03<00:08,  3.42it/s]
# Generating for node: 25:  27%|██▋       | 11/41 [00:03<00:08,  3.42it/s]
# Generating for node: 25:  29%|██▉       | 12/41 [00:03<00:08,  3.27it/s]
# Generating for node: 28:  29%|██▉       | 12/41 [00:03<00:08,  3.27it/s]
# Generating for node: 28:  32%|███▏      | 13/41 [00:03<00:08,  3.15it/s]
# Generating for node: 26:  32%|███▏      | 13/41 [00:03<00:08,  3.15it/s]
# Generating for node: 26:  34%|███▍      | 14/41 [00:04<00:08,  3.10it/s]
# Generating for node: 2:  34%|███▍      | 14/41 [00:04<00:08,  3.10it/s]
# Generating for node: 2:  37%|███▋      | 15/41 [00:04<00:08,  3.03it/s]
# Generating for node: 8:  37%|███▋      | 15/41 [00:04<00:08,  3.03it/s]/Users/maxbaak/Projects/pgmpy/pgmpy/factors/discrete/DiscreteFactor.py:517: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   warn(
#
# Generating for node: 8:  39%|███▉      | 16/41 [00:04<00:08,  3.11it/s]
# Generating for node: 14:  39%|███▉      | 16/41 [00:04<00:08,  3.11it/s]
# Generating for node: 14:  41%|████▏     | 17/41 [00:05<00:07,  3.21it/s]
# Generating for node: 6:  41%|████▏     | 17/41 [00:05<00:07,  3.21it/s]
# Generating for node: 6:  44%|████▍     | 18/41 [00:05<00:06,  3.29it/s]
# Generating for node: 17:  44%|████▍     | 18/41 [00:05<00:06,  3.29it/s]
# Generating for node: 17:  46%|████▋     | 19/41 [00:05<00:06,  3.36it/s]
# Generating for node: 10:  46%|████▋     | 19/41 [00:05<00:06,  3.36it/s]
# Generating for node: 10:  49%|████▉     | 20/41 [00:05<00:06,  3.43it/s]
# Generating for node: 18:  49%|████▉     | 20/41 [00:05<00:06,  3.43it/s]
# Generating for node: 18:  51%|█████     | 21/41 [00:06<00:05,  3.45it/s]
# Generating for node: 16:  51%|█████     | 21/41 [00:06<00:05,  3.45it/s]
# Generating for node: 16:  54%|█████▎    | 22/41 [00:06<00:05,  3.33it/s]
# Generating for node: 15:  54%|█████▎    | 22/41 [00:06<00:05,  3.33it/s]
# Generating for node: 15:  56%|█████▌    | 23/41 [00:06<00:05,  3.24it/s]
# Generating for node: 22:  56%|█████▌    | 23/41 [00:06<00:05,  3.24it/s]
# Generating for node: 22:  59%|█████▊    | 24/41 [00:07<00:05,  3.20it/s]
# Generating for node: 21:  59%|█████▊    | 24/41 [00:07<00:05,  3.20it/s]
# Generating for node: 21:  61%|██████    | 25/41 [00:07<00:05,  3.17it/s]
# Generating for node: 20:  61%|██████    | 25/41 [00:07<00:05,  3.17it/s]
# Generating for node: 20:  63%|██████▎   | 26/41 [00:07<00:04,  3.25it/s]
# Generating for node: 9:  63%|██████▎   | 26/41 [00:07<00:04,  3.25it/s]
# Generating for node: 9:  66%|██████▌   | 27/41 [00:08<00:04,  3.15it/s]
# Generating for node: 23:  66%|██████▌   | 27/41 [00:08<00:04,  3.15it/s]
# Generating for node: 23:  68%|██████▊   | 28/41 [00:08<00:04,  3.15it/s]
# Generating for node: 34:  68%|██████▊   | 28/41 [00:08<00:04,  3.15it/s]
# Generating for node: 34:  71%|███████   | 29/41 [00:08<00:03,  3.08it/s]
# Generating for node: 12:  71%|███████   | 29/41 [00:08<00:03,  3.08it/s]
# Generating for node: 12:  73%|███████▎  | 30/41 [00:09<00:03,  3.03it/s]
# Generating for node: 27:  73%|███████▎  | 30/41 [00:09<00:03,  3.03it/s]
# Generating for node: 27:  76%|███████▌  | 31/41 [00:09<00:03,  3.04it/s]
# Generating for node: 38:  76%|███████▌  | 31/41 [00:09<00:03,  3.04it/s]
# Generating for node: 38:  78%|███████▊  | 32/41 [00:09<00:02,  3.03it/s]
# Generating for node: 36:  78%|███████▊  | 32/41 [00:09<00:02,  3.03it/s]
# Generating for node: 36:  80%|████████  | 33/41 [00:10<00:02,  3.00it/s]
# Generating for node: 37:  80%|████████  | 33/41 [00:10<00:02,  3.00it/s]
# Generating for node: 37:  83%|████████▎ | 34/41 [00:10<00:02,  3.00it/s]
# Generating for node: 11:  83%|████████▎ | 34/41 [00:10<00:02,  3.00it/s]
# Generating for node: 11:  85%|████████▌ | 35/41 [00:10<00:01,  3.03it/s]
# Generating for node: 19:  85%|████████▌ | 35/41 [00:10<00:01,  3.03it/s]
# Generating for node: 19:  88%|████████▊ | 36/41 [00:11<00:01,  3.18it/s]
# Generating for node: 4:  88%|████████▊ | 36/41 [00:11<00:01,  3.18it/s]
# Generating for node: 4:  90%|█████████ | 37/41 [00:11<00:01,  3.13it/s]
# Generating for node: 29:  90%|█████████ | 37/41 [00:11<00:01,  3.13it/s]
# Generating for node: 29:  93%|█████████▎| 38/41 [00:11<00:00,  3.08it/s]
# Generating for node: 24:  93%|█████████▎| 38/41 [00:11<00:00,  3.08it/s]
# Generating for node: 24:  95%|█████████▌| 39/41 [00:12<00:00,  3.07it/s]
# Generating for node: 40:  95%|█████████▌| 39/41 [00:12<00:00,  3.07it/s]
# Generating for node: 40:  98%|█████████▊| 40/41 [00:12<00:00,  3.11it/s]
# Generating for node: 13:  98%|█████████▊| 40/41 [00:12<00:00,  3.11it/s]
# Generating for node: 13: 100%|██████████| 41/41 [00:12<00:00,  3.24it/s]
# INFO:sdgym.benchmark:Scoring KDECopulaNNPdf_SynthesizerInteger on dataset intrusion; iteration 0; 926.15 MB
# [[ 3.5614783e-01  1.0000000e+00  1.0000000e+00  1.0000000e+00
#    4.0846428e+03]
#  [ 6.2063038e-01  0.0000000e+00  0.0000000e+00  0.0000000e+00
#   -2.6159861e+03]
#  [-3.7880585e-01  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   -2.6516339e+02]
#  ...
#  [-3.5882361e-02  1.0000000e+00  1.0000000e+00  1.0000000e+00
#   -3.2009357e+02]
#  [ 9.7072080e-02  0.0000000e+00  0.0000000e+00  0.0000000e+00
#    3.7860693e+03]
#  [-1.4612874e-01  1.0000000e+00  1.0000000e+00  1.0000000e+00
#    7.0037012e+02]]
# [[ 0.000e+00  1.000e+00  1.000e+00  1.000e+00  4.085e+03]
#  [ 1.000e+00  0.000e+00  0.000e+00  0.000e+00 -2.616e+03]
#  [-0.000e+00  1.000e+00  1.000e+00  1.000e+00 -2.650e+02]
#  ...
#  [-0.000e+00  1.000e+00  1.000e+00  1.000e+00 -3.200e+02]
#  [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  3.786e+03]
#  [-0.000e+00  1.000e+00  1.000e+00  1.000e+00  7.000e+02]]
# INFO:sdgym.evaluate:Evaluating using multiclass classifier DecisionTreeClassifier
# INFO:sdgym.evaluate:Evaluating using multiclass classifier MLPClassifier
# /Users/maxbaak/opt/miniconda3/envs/synthsonic/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# INFO:sdgym.benchmark:Finished KDECopulaNNPdf_SynthesizerInteger on dataset intrusion; iteration 0; 1.23 GB
# INFO:sdgym.benchmark:100%|##########| 1/1 [08:05<00:00, 485.68s/it]
# INFO:sdgym.benchmark:100%|##########| 1/1 [08:05<00:00, 485.68s/it]

# %%
# n_bins = 25; distinct = -1
scores
# Out:
#                                    intrusion/accuracy  intrusion/macro_f1  \
# VEEGANSynthesizer                            0.506413            0.180797
# CLBNSynthesizer                              0.940990            0.385243
# CTGAN                                        0.982863            0.540598
# CTGANSynthesizer                             0.976640            0.510842
# CopulaGAN                                    0.978257            0.516588
# GaussianCopulaCategorical                    0.792053            0.176792
# GaussianCopulaCategoricalFuzzy               0.843653            0.256447
# GaussianCopulaOneHot                         0.904267            0.331106
# IdentitySynthesizer                          0.999150            0.863171
# IndependentSynthesizer                       0.722643            0.198038
# MedganSynthesizer                            0.867310            0.274576
# PrivBNSynthesizer                            0.948697            0.382637
# TVAESynthesizer                              0.974620            0.432752
# TableganSynthesizer                               NaN                 NaN
# UniformSynthesizer                           0.121007            0.065334
# KDECopulaNNPdf_SynthesizerInteger            0.988690            0.590213
#
#                                    intrusion/micro_f1  \
# VEEGANSynthesizer                            0.506413
# CLBNSynthesizer                              0.940990
# CTGAN                                        0.982863
# CTGANSynthesizer                             0.976640
# CopulaGAN                                    0.978257
# GaussianCopulaCategorical                    0.792053
# GaussianCopulaCategoricalFuzzy               0.843653
# GaussianCopulaOneHot                         0.904267
# IdentitySynthesizer                          0.999150
# IndependentSynthesizer                       0.722643
# MedganSynthesizer                            0.867310
# PrivBNSynthesizer                            0.948697
# TVAESynthesizer                              0.974620
# TableganSynthesizer                               NaN
# UniformSynthesizer                           0.121007
# KDECopulaNNPdf_SynthesizerInteger            0.988690
#
#                                                    timestamp
# VEEGANSynthesizer                 2020-04-12 09:41:35.096775
# CLBNSynthesizer                   2020-10-17 09:46:54.494331
# CTGAN                             2020-10-17 09:46:54.494331
# CTGANSynthesizer                  2020-10-17 09:46:54.494331
# CopulaGAN                         2020-10-17 09:46:54.494331
# GaussianCopulaCategorical         2020-10-17 09:46:54.494331
# GaussianCopulaCategoricalFuzzy    2020-10-17 09:46:54.494331
# GaussianCopulaOneHot              2020-10-17 09:46:54.494331
# IdentitySynthesizer               2020-10-17 09:46:54.494331
# IndependentSynthesizer            2020-10-17 09:46:54.494331
# MedganSynthesizer                 2020-10-17 09:46:54.494331
# PrivBNSynthesizer                 2020-10-17 09:46:54.494331
# TVAESynthesizer                   2020-10-17 09:46:54.494331
# TableganSynthesizer               2020-10-17 09:46:54.494331
# UniformSynthesizer                2020-10-17 09:46:54.494331
# KDECopulaNNPdf_SynthesizerInteger 2021-05-13 20:15:43.016700

# %%
scores.tail(4)
# Out:
#                                    intrusion/accuracy  intrusion/macro_f1  \
# TVAESynthesizer                              0.974620            0.432752
# TableganSynthesizer                               NaN                 NaN
# UniformSynthesizer                           0.121007            0.065334
# KDECopulaNNPdf_SynthesizerInteger            0.988690            0.590213
#
#                                    intrusion/micro_f1  \
# TVAESynthesizer                              0.974620
# TableganSynthesizer                               NaN
# UniformSynthesizer                           0.121007
# KDECopulaNNPdf_SynthesizerInteger            0.988690
#
#                                                    timestamp
# TVAESynthesizer                   2020-10-17 09:46:54.494331
# TableganSynthesizer               2020-10-17 09:46:54.494331
# UniformSynthesizer                2020-10-17 09:46:54.494331
# KDECopulaNNPdf_SynthesizerInteger 2021-05-13 20:15:43.016700
