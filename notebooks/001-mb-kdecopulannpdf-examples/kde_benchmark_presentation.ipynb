# %% [markdown]
# ### This notebook is used to perform gridsearch on asia dataset

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from sdgym import benchmark
from sdgym import load_dataset
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from synthsonic.models.kde_copula_nn_pdf import KDECopulaNNPdf
from synthsonic.models.categorical_utils import categorical_round, vec_translate, categorical_frequency_mapping, \
            categorical_frequency_inverse_mapping, encode_one_hot, decode_one_hot
from timeit import default_timer as timer
# %matplotlib inline

# %%
from functools import partial

# %% [markdown]
# ### Gaussian Mixtures datasets

# %%
def KDECopulaNNPdf_RoundCategorical(real_data, categorical_columns, ordinal_columns):
    # Max's kde copula model with default parameters
    all_features = list(range(real_data.shape[1]))
    numerical_features = list(set(all_features) - set(categorical_columns + ordinal_columns))
    data = np.float64(real_data)
    
    n_samples = data.shape[0]
    n_features = data.shape[1]
    
    kde = KDECopulaNNPdf(use_KDE=False, clf=MLPClassifier(alpha=0.1, random_state=0, max_iter=1000, early_stopping=True))
    kde = kde.fit(data)
    
    X_gen, sample_weight = kde.sample(n_samples)
    
    X_gen[:, categorical_columns+ordinal_columns] = np.round(X_gen[:, categorical_columns+ordinal_columns])
    X_gen = np.float32(X_gen)
    return X_gen

# %%
grid_scores = benchmark(synthesizers=[KDECopulaNNPdf_RoundCategorical], datasets=['grid'])
# Out:
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 2
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 2
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 2

# %%
def KDECopulaNNPdf_RoundCategorical(real_data, categorical_columns, ordinal_columns):
    # Max's kde copula model with default parameters
    all_features = list(range(real_data.shape[1]))
    numerical_features = list(set(all_features) - set(categorical_columns + ordinal_columns))
    data = np.float64(real_data)
    
    n_samples = data.shape[0]
    n_features = data.shape[1]
    
    kde = KDECopulaNNPdf(use_KDE=False, clf=XGBClassifier(n_estimators=50, reg_lambda=1, gamma=0, max_depth=2))
    kde = kde.fit(data)
    
    X_gen, sample_weight = kde.sample(n_samples)
    
    X_gen[:, categorical_columns+ordinal_columns] = np.round(X_gen[:, categorical_columns+ordinal_columns])
    X_gen = np.float32(X_gen)
    return X_gen

# %%
gridr_scores = benchmark(synthesizers=[KDECopulaNNPdf_RoundCategorical], datasets=['gridr'])
# Out:
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 2
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 2
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 2

# %%
def KDECopulaNNPdf_RoundCategorical(real_data, categorical_columns, ordinal_columns):
    # Max's kde copula model with default parameters
    all_features = list(range(real_data.shape[1]))
    numerical_features = list(set(all_features) - set(categorical_columns + ordinal_columns))
    data = np.float64(real_data)
    
    n_samples = data.shape[0]
    n_features = data.shape[1]
    
    kde = KDECopulaNNPdf(use_KDE=False, clf=XGBClassifier(n_estimators=50, reg_lambda=1, gamma=0, max_depth=2))
    kde = kde.fit(data)
    
    X_gen, sample_weight = kde.sample(n_samples)
    
    X_gen[:, categorical_columns+ordinal_columns] = np.round(X_gen[:, categorical_columns+ordinal_columns])
    X_gen = np.float32(X_gen)
    return X_gen

# %%
ring_scores = benchmark(synthesizers=[KDECopulaNNPdf_RoundCategorical], datasets=['ring'])
# Out:
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 2
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 2
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 2

# %%
gm_scores = pd.concat([grid_scores, gridr_scores, ring_scores], axis=1)
gm_scores
# Out:
#                                  grid/syn_likelihood  grid/test_likelihood  \
# CLBNSynthesizer                            -3.885928             -5.274841
# CTGANSynthesizer                           -9.162882             -5.066747
# IdentitySynthesizer                        -3.476662             -3.503242
# IndependentSynthesizer                     -3.544136             -3.469971
# MedganSynthesizer                          -6.833268            -84.380587
# TableganSynthesizer                        -6.777964             -4.931756
# TVAESynthesizer                            -3.388274             -5.190146
# UniformSynthesizer                         -7.294052             -4.534827
# VEEGANSynthesizer                          -8.646858           -423.573276
# KDECopulaNNPdf_RoundCategorical            -3.558267             -3.444570
#
#                                                  timestamp  \
# CLBNSynthesizer                 2020-04-12 09:41:35.096775
# CTGANSynthesizer                2020-04-12 09:41:35.096775
# IdentitySynthesizer             2020-04-12 09:41:35.096775
# IndependentSynthesizer          2020-04-12 09:41:35.096775
# MedganSynthesizer               2020-04-12 09:41:35.096775
# TableganSynthesizer             2020-04-12 09:41:35.096775
# TVAESynthesizer                 2020-04-12 09:41:35.096775
# UniformSynthesizer              2020-04-12 09:41:35.096775
# VEEGANSynthesizer               2020-04-12 09:41:35.096775
# KDECopulaNNPdf_RoundCategorical 2020-09-25 10:03:56.192125
#
#                                  grid/exec_time (s)  gridr/syn_likelihood  \
# CLBNSynthesizer                                 NaN             -4.066210
# CTGANSynthesizer                                NaN             -8.653293
# IdentitySynthesizer                             NaN             -3.607534
# IndependentSynthesizer                          NaN             -5.033312
# MedganSynthesizer                               NaN             -7.747477
# TableganSynthesizer                             NaN             -7.080974
# TVAESynthesizer                                 NaN             -3.820569
# UniformSynthesizer                              NaN             -7.227006
# VEEGANSynthesizer                               NaN            -11.458546
# KDECopulaNNPdf_RoundCategorical            2.276635             -4.922486
#
#                                  gridr/test_likelihood  \
# CLBNSynthesizer                             -10.287411
# CTGANSynthesizer                             -5.086304
# IdentitySynthesizer                          -3.635514
# IndependentSynthesizer                       -4.037670
# MedganSynthesizer                          -160.899159
# TableganSynthesizer                          -5.047245
# TVAESynthesizer                              -3.724633
# UniformSynthesizer                           -4.549560
# VEEGANSynthesizer                            -8.908475
# KDECopulaNNPdf_RoundCategorical              -4.016792
#
#                                                  timestamp  \
# CLBNSynthesizer                 2020-04-12 09:41:35.096775
# CTGANSynthesizer                2020-04-12 09:41:35.096775
# IdentitySynthesizer             2020-04-12 09:41:35.096775
# IndependentSynthesizer          2020-04-12 09:41:35.096775
# MedganSynthesizer               2020-04-12 09:41:35.096775
# TableganSynthesizer             2020-04-12 09:41:35.096775
# TVAESynthesizer                 2020-04-12 09:41:35.096775
# UniformSynthesizer              2020-04-12 09:41:35.096775
# VEEGANSynthesizer               2020-04-12 09:41:35.096775
# KDECopulaNNPdf_RoundCategorical 2020-09-25 10:04:01.601808
#
#                                  gridr/exec_time (s)  ring/syn_likelihood  \
# CLBNSynthesizer                                  NaN            -1.750592
# CTGANSynthesizer                                 NaN            -7.056122
# IdentitySynthesizer                              NaN            -1.713405
# IndependentSynthesizer                           NaN            -2.465557
# MedganSynthesizer                                NaN            -2.769543
# TableganSynthesizer                              NaN            -3.898531
# TVAESynthesizer                                  NaN            -1.654247
# UniformSynthesizer                               NaN            -5.343589
# VEEGANSynthesizer                                NaN           -16.830634
# KDECopulaNNPdf_RoundCategorical             1.207815            -1.993645
#
#                                  ring/test_likelihood  \
# CLBNSynthesizer                            -18.904815
# CTGANSynthesizer                            -2.737149
# IdentitySynthesizer                         -1.704359
# IndependentSynthesizer                      -1.965117
# MedganSynthesizer                         -133.462900
# TableganSynthesizer                         -2.307308
# TVAESynthesizer                             -1.933056
# UniformSynthesizer                          -2.520734
# VEEGANSynthesizer                           -6.354960
# KDECopulaNNPdf_RoundCategorical             -1.823200
#
#                                                  timestamp  ring/exec_time (s)
# CLBNSynthesizer                 2020-04-12 09:41:35.096775                 NaN
# CTGANSynthesizer                2020-04-12 09:41:35.096775                 NaN
# IdentitySynthesizer             2020-04-12 09:41:35.096775                 NaN
# IndependentSynthesizer          2020-04-12 09:41:35.096775                 NaN
# MedganSynthesizer               2020-04-12 09:41:35.096775                 NaN
# TableganSynthesizer             2020-04-12 09:41:35.096775                 NaN
# TVAESynthesizer                 2020-04-12 09:41:35.096775                 NaN
# UniformSynthesizer              2020-04-12 09:41:35.096775                 NaN
# VEEGANSynthesizer               2020-04-12 09:41:35.096775                 NaN
# KDECopulaNNPdf_RoundCategorical 2020-09-25 10:04:07.451129            1.235614

# %% [markdown]
# ### Bayesian Networks datasets

# %%
def KDECopulaNNPdf_RoundCategorical(real_data, categorical_columns, ordinal_columns):
    # Max's kde copula model with default parameters
    all_features = list(range(real_data.shape[1]))
    numerical_features = list(set(all_features) - set(categorical_columns + ordinal_columns))
    data = np.float64(real_data)
    
    n_samples = data.shape[0]
    n_features = data.shape[1]
    
    kde = KDECopulaNNPdf(use_KDE=False, clf=MLPClassifier(hidden_layer_sizes=(100,), alpha=0.05, \
                                            max_iter=500, early_stopping=True, random_state=0))
    kde = kde.fit(data)
    
    X_gen, sample_weight = kde.sample(n_samples)
    
    X_gen[:, categorical_columns+ordinal_columns] = np.round(X_gen[:, categorical_columns+ordinal_columns])
    X_gen = np.float32(X_gen)
    return X_gen

# %%
asia_scores = benchmark(synthesizers=[KDECopulaNNPdf_RoundCategorical], datasets=['asia'])
# Out:
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 8
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 8
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 8

# %%
def KDECopulaNNPdf_RoundCategorical(real_data, categorical_columns, ordinal_columns):
    # Max's kde copula model with default parameters
    all_features = list(range(real_data.shape[1]))
    numerical_features = list(set(all_features) - set(categorical_columns + ordinal_columns))
    data = np.float64(real_data)
    
    n_samples = data.shape[0]
    n_features = data.shape[1]
    
    kde = KDECopulaNNPdf(force_uncorrelated=True, use_KDE=False, clf=XGBClassifier(max_depth=3))
    kde = kde.fit(data)
    
    X_gen, sample_weight = kde.sample(n_samples)
    
    X_gen[:, categorical_columns+ordinal_columns] = np.round(X_gen[:, categorical_columns+ordinal_columns])
    X_gen = np.float32(X_gen)
    return X_gen

# %%
alarm_scores = benchmark(synthesizers=[KDECopulaNNPdf_RoundCategorical], datasets=['alarm'])
# Out:
# Transforming variables.
# Model = rho: 0.5, number of selected non-linear variables: 0
# Transforming variables.
# Model = rho: 0.5, number of selected non-linear variables: 0
# Transforming variables.
# Model = rho: 0.5, number of selected non-linear variables: 0

# %%
# To do - was unable to do gridsearch for child and insurance datasets
def KDECopulaNNPdf_RoundCategorical(real_data, categorical_columns, ordinal_columns):
    # Max's kde copula model with default parameters
    all_features = list(range(real_data.shape[1]))
    numerical_features = list(set(all_features) - set(categorical_columns + ordinal_columns))
    data = np.float64(real_data)
    
    n_samples = data.shape[0]
    n_features = data.shape[1]
    
    kde = KDECopulaNNPdf(use_KDE=False, clf=MLPClassifier(random_state=0, max_iter=500, early_stopping=True))
    kde = kde.fit(data)
    
    X_gen, sample_weight = kde.sample(n_samples)
    
    X_gen[:, categorical_columns+ordinal_columns] = np.round(X_gen[:, categorical_columns+ordinal_columns])
    X_gen = np.float32(X_gen)
    return X_gen

# %%
child_scores = benchmark(synthesizers=[KDECopulaNNPdf_RoundCategorical], datasets=['child'])
# Out:
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 20
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 20
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 20

# %%
insurance_scores = benchmark(synthesizers=[KDECopulaNNPdf_RoundCategorical], datasets=['insurance'])
# Out:
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 27
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 27
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 27

# %%
bn_scores = pd.concat([asia_scores, alarm_scores, child_scores, insurance_scores], axis=1)
bn_scores
#bn_scores.loc[:, ~bn_scores.columns.str.endswith('syn_likelihood')]
# Out:
#                                  asia/syn_likelihood  asia/test_likelihood  \
# CLBNSynthesizer                            -2.406589             -2.271840
# CTGANSynthesizer                           -3.886903             -2.442375
# IdentitySynthesizer                        -2.250748             -2.241122
# IndependentSynthesizer                     -4.933314             -3.001627
# MedganSynthesizer                          -1.519422             -5.197981
# TableganSynthesizer                        -3.331052             -2.684490
# TVAESynthesizer                            -2.353327             -2.267334
# UniformSynthesizer                        -14.301042             -5.551594
# VEEGANSynthesizer                         -11.492287             -5.952712
# KDECopulaNNPdf_RoundCategorical            -4.478556             -2.633132
#
#                                                  timestamp  \
# CLBNSynthesizer                 2020-04-12 09:41:35.096775
# CTGANSynthesizer                2020-04-12 09:41:35.096775
# IdentitySynthesizer             2020-04-12 09:41:35.096775
# IndependentSynthesizer          2020-04-12 09:41:35.096775
# MedganSynthesizer               2020-04-12 09:41:35.096775
# TableganSynthesizer             2020-04-12 09:41:35.096775
# TVAESynthesizer                 2020-04-12 09:41:35.096775
# UniformSynthesizer              2020-04-12 09:41:35.096775
# VEEGANSynthesizer               2020-04-12 09:41:35.096775
# KDECopulaNNPdf_RoundCategorical 2020-09-25 10:04:31.962226
#
#                                  asia/exec_time (s)  alarm/syn_likelihood  \
# CLBNSynthesizer                                 NaN            -12.385436
# CTGANSynthesizer                                NaN            -15.625477
# IdentitySynthesizer                             NaN            -10.233935
# IndependentSynthesizer                          NaN            -18.230315
# MedganSynthesizer                               NaN             -8.169461
# TableganSynthesizer                             NaN            -12.744195
# TVAESynthesizer                                 NaN            -11.357112
# UniformSynthesizer                              NaN            -18.420681
# VEEGANSynthesizer                               NaN            -18.386073
# KDECopulaNNPdf_RoundCategorical            6.847341            -18.232053
#
#                                  alarm/test_likelihood  \
# CLBNSynthesizer                             -11.181650
# CTGANSynthesizer                            -12.915224
# IdentitySynthesizer                         -10.301955
# IndependentSynthesizer                      -15.805230
# MedganSynthesizer                           -13.020430
# TableganSynthesizer                         -11.565230
# TVAESynthesizer                             -10.754935
# UniformSynthesizer                          -18.420681
# VEEGANSynthesizer                           -18.210907
# KDECopulaNNPdf_RoundCategorical             -15.818839
#
#                                                  timestamp  \
# CLBNSynthesizer                 2020-04-12 09:41:35.096775
# CTGANSynthesizer                2020-04-12 09:41:35.096775
# IdentitySynthesizer             2020-04-12 09:41:35.096775
# IndependentSynthesizer          2020-04-12 09:41:35.096775
# MedganSynthesizer               2020-04-12 09:41:35.096775
# TableganSynthesizer             2020-04-12 09:41:35.096775
# TVAESynthesizer                 2020-04-12 09:41:35.096775
# UniformSynthesizer              2020-04-12 09:41:35.096775
# VEEGANSynthesizer               2020-04-12 09:41:35.096775
# KDECopulaNNPdf_RoundCategorical 2020-09-25 10:04:49.132418
#
#                                  alarm/exec_time (s)  child/syn_likelihood  \
# CLBNSynthesizer                                  NaN            -12.636520
# CTGANSynthesizer                                 NaN            -14.044374
# IdentitySynthesizer                              NaN            -12.045682
# IndependentSynthesizer                           NaN            -17.949428
# MedganSynthesizer                                NaN            -11.198930
# TableganSynthesizer                              NaN            -14.768575
# TVAESynthesizer                                  NaN            -12.285050
# UniformSynthesizer                               NaN            -18.409743
# VEEGANSynthesizer                                NaN            -17.314284
# KDECopulaNNPdf_RoundCategorical             0.987491            -17.315450
#
#                                  child/test_likelihood  \
# CLBNSynthesizer                             -12.307927
# CTGANSynthesizer                            -12.832626
# IdentitySynthesizer                         -12.041519
# IndependentSynthesizer                      -16.045038
# MedganSynthesizer                           -13.099122
# TableganSynthesizer                         -13.241063
# TVAESynthesizer                             -12.248007
# UniformSynthesizer                          -18.333704
# VEEGANSynthesizer                           -17.681452
# KDECopulaNNPdf_RoundCategorical             -14.818844
#
#                                                  timestamp  \
# CLBNSynthesizer                 2020-04-12 09:41:35.096775
# CTGANSynthesizer                2020-04-12 09:41:35.096775
# IdentitySynthesizer             2020-04-12 09:41:35.096775
# IndependentSynthesizer          2020-04-12 09:41:35.096775
# MedganSynthesizer               2020-04-12 09:41:35.096775
# TableganSynthesizer             2020-04-12 09:41:35.096775
# TVAESynthesizer                 2020-04-12 09:41:35.096775
# UniformSynthesizer              2020-04-12 09:41:35.096775
# VEEGANSynthesizer               2020-04-12 09:41:35.096775
# KDECopulaNNPdf_RoundCategorical 2020-09-25 10:05:37.609636
#
#                                  child/exec_time (s)  \
# CLBNSynthesizer                                  NaN
# CTGANSynthesizer                                 NaN
# IdentitySynthesizer                              NaN
# IndependentSynthesizer                           NaN
# MedganSynthesizer                                NaN
# TableganSynthesizer                              NaN
# TVAESynthesizer                                  NaN
# UniformSynthesizer                               NaN
# VEEGANSynthesizer                                NaN
# KDECopulaNNPdf_RoundCategorical            13.056866
#
#                                  insurance/syn_likelihood  \
# CLBNSynthesizer                                -15.206133
# CTGANSynthesizer                               -16.917861
# IdentitySynthesizer                            -12.850257
# IndependentSynthesizer                         -18.381496
# MedganSynthesizer                              -13.801601
# TableganSynthesizer                            -16.087381
# TVAESynthesizer                                -14.293042
# UniformSynthesizer                             -18.420681
# VEEGANSynthesizer                              -18.325827
# KDECopulaNNPdf_RoundCategorical                -18.078246
#
#                                  insurance/test_likelihood  \
# CLBNSynthesizer                                 -13.917471
# CTGANSynthesizer                                -14.961379
# IdentitySynthesizer                             -12.959072
# IndependentSynthesizer                          -17.563807
# MedganSynthesizer                               -14.943327
# TableganSynthesizer                             -14.299552
# TVAESynthesizer                                 -13.823180
# UniformSynthesizer                              -18.420677
# VEEGANSynthesizer                               -18.113419
# KDECopulaNNPdf_RoundCategorical                 -16.205101
#
#                                                  timestamp  \
# CLBNSynthesizer                 2020-04-12 09:41:35.096775
# CTGANSynthesizer                2020-04-12 09:41:35.096775
# IdentitySynthesizer             2020-04-12 09:41:35.096775
# IndependentSynthesizer          2020-04-12 09:41:35.096775
# MedganSynthesizer               2020-04-12 09:41:35.096775
# TableganSynthesizer             2020-04-12 09:41:35.096775
# TVAESynthesizer                 2020-04-12 09:41:35.096775
# UniformSynthesizer              2020-04-12 09:41:35.096775
# VEEGANSynthesizer               2020-04-12 09:41:35.096775
# KDECopulaNNPdf_RoundCategorical 2020-09-25 10:06:22.725199
#
#                                  insurance/exec_time (s)
# CLBNSynthesizer                                      NaN
# CTGANSynthesizer                                     NaN
# IdentitySynthesizer                                  NaN
# IndependentSynthesizer                               NaN
# MedganSynthesizer                                    NaN
# TableganSynthesizer                                  NaN
# TVAESynthesizer                                      NaN
# UniformSynthesizer                                   NaN
# VEEGANSynthesizer                                    NaN
# KDECopulaNNPdf_RoundCategorical                10.782787

# %% [markdown]
# ### Real world datasets

# %%
def KDECopulaNNPdf_RoundCategorical(real_data, categorical_columns, ordinal_columns):
    # Max's kde copula model with default parameters
    all_features = list(range(real_data.shape[1]))
    numerical_features = list(set(all_features) - set(categorical_columns + ordinal_columns))
    data = np.float64(real_data)
    
    n_samples = data.shape[0]
    n_features = data.shape[1]
    
    kde = KDECopulaNNPdf(use_KDE=False, clf=XGBClassifier(random_state=0, n_estimators=100, reg_lambda=1, gamma=0, max_depth=3))
    kde = kde.fit(data)
    
    X_gen, sample_weight = kde.sample(n_samples)
    
    X_gen[:, categorical_columns+ordinal_columns] = np.round(X_gen[:, categorical_columns+ordinal_columns])
    X_gen = np.float32(X_gen)
    return X_gen

# %%
adult_scores = benchmark(synthesizers=[KDECopulaNNPdf_RoundCategorical], datasets=['adult'])
# Out:
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 14
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 14
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 14
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
def KDECopulaNNPdf_RoundCategorical(real_data, categorical_columns, ordinal_columns):
    # Max's kde copula model with default parameters
    all_features = list(range(real_data.shape[1]))
    numerical_features = list(set(all_features) - set(categorical_columns + ordinal_columns))
    data = np.float64(real_data)
    
    n_samples = data.shape[0]
    n_features = data.shape[1]
    
    kde = KDECopulaNNPdf(force_uncorrelated=False, use_KDE=False, n_nonlinear_vars=36, clf=XGBClassifier(max_depth=3, n_estimators=250))
    kde = kde.fit(data)
    
    X_gen, sample_weight = kde.sample(n_samples)
    
    X_gen[:, categorical_columns+ordinal_columns] = np.round(X_gen[:, categorical_columns+ordinal_columns])
    X_gen = np.float32(X_gen)
    return X_gen

# %%
intrusion_scores = benchmark(synthesizers=[KDECopulaNNPdf_RoundCategorical], datasets=['intrusion'])
# Out:
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 36
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/metrics/classification.py:1436: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   precision = _prf_divide(tp_sum, pred_sum,
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 36
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/metrics/classification.py:1436: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   precision = _prf_divide(tp_sum, pred_sum,
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 36
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/metrics/classification.py:1436: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   precision = _prf_divide(tp_sum, pred_sum,

# %%
def KDECopulaNNPdf_RoundCategorical(real_data, categorical_columns, ordinal_columns):
    # Max's kde copula model with default parameters
    all_features = list(range(real_data.shape[1]))
    numerical_features = list(set(all_features) - set(categorical_columns + ordinal_columns))
    data = np.float64(real_data)
    
    n_samples = data.shape[0]
    n_features = data.shape[1]
    
    kde = KDECopulaNNPdf(use_KDE=False, clf=MLPClassifier(random_state=0, max_iter=500, early_stopping=True))
    kde = kde.fit(data)
    
    X_gen, sample_weight = kde.sample(n_samples)
    
    X_gen[:, categorical_columns+ordinal_columns] = np.round(X_gen[:, categorical_columns+ordinal_columns])
    X_gen = np.float32(X_gen)
    return X_gen

# %%
census_scores = benchmark(synthesizers=[KDECopulaNNPdf_RoundCategorical], datasets=['census'])
# Out:
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 35
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/metrics/classification.py:1436: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   precision = _prf_divide(tp_sum, pred_sum,
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 35
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/metrics/classification.py:1436: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   precision = _prf_divide(tp_sum, pred_sum,
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 35
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/metrics/classification.py:1436: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   precision = _prf_divide(tp_sum, pred_sum,
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
rw_scores = pd.concat([adult_scores, intrusion_scores, census_scores], axis=1)
rw_scores
# Out:
#                                  adult/accuracy  adult/f1  \
# CLBNSynthesizer                        0.760117  0.291326
# CTGANSynthesizer                       0.784217  0.597420
# IdentitySynthesizer                    0.825608  0.661600
# IndependentSynthesizer                 0.654425  0.174515
# MedganSynthesizer                      0.593683  0.276167
# TableganSynthesizer                    0.798850  0.426258
# TVAESynthesizer                        0.810817  0.630175
# UniformSynthesizer                     0.500242  0.301878
# VEEGANSynthesizer                      0.718792  0.162142
# KDECopulaNNPdf_RoundCategorical        0.743825  0.402500
#
#                                                  timestamp  \
# CLBNSynthesizer                 2020-04-12 09:41:35.096775
# CTGANSynthesizer                2020-04-12 09:41:35.096775
# IdentitySynthesizer             2020-04-12 09:41:35.096775
# IndependentSynthesizer          2020-04-12 09:41:35.096775
# MedganSynthesizer               2020-04-12 09:41:35.096775
# TableganSynthesizer             2020-04-12 09:41:35.096775
# TVAESynthesizer                 2020-04-12 09:41:35.096775
# UniformSynthesizer              2020-04-12 09:41:35.096775
# VEEGANSynthesizer               2020-04-12 09:41:35.096775
# KDECopulaNNPdf_RoundCategorical 2020-09-25 10:07:15.902792
#
#                                  adult/exec_time (s)  intrusion/accuracy  \
# CLBNSynthesizer                                  NaN            0.887753
# CTGANSynthesizer                                 NaN            0.973317
# IdentitySynthesizer                              NaN            0.999083
# IndependentSynthesizer                           NaN            0.554480
# MedganSynthesizer                                NaN            0.759467
# TableganSynthesizer                              NaN                 NaN
# TVAESynthesizer                                  NaN            0.977433
# UniformSynthesizer                               NaN            0.103120
# VEEGANSynthesizer                                NaN            0.506413
# KDECopulaNNPdf_RoundCategorical            10.779987            0.911330
#
#                                  intrusion/macro_f1  intrusion/micro_f1  \
# CLBNSynthesizer                            0.343114            0.887753
# CTGANSynthesizer                           0.483286            0.973317
# IdentitySynthesizer                        0.867048            0.999083
# IndependentSynthesizer                     0.148850            0.554480
# MedganSynthesizer                          0.270662            0.759467
# TableganSynthesizer                             NaN                 NaN
# TVAESynthesizer                            0.461439            0.977433
# UniformSynthesizer                         0.080952            0.103120
# VEEGANSynthesizer                          0.180797            0.506413
# KDECopulaNNPdf_RoundCategorical            0.337918            0.911330
#
#                                                  timestamp  \
# CLBNSynthesizer                 2020-04-12 09:41:35.096775
# CTGANSynthesizer                2020-04-12 09:41:35.096775
# IdentitySynthesizer             2020-04-12 09:41:35.096775
# IndependentSynthesizer          2020-04-12 09:41:35.096775
# MedganSynthesizer               2020-04-12 09:41:35.096775
# TableganSynthesizer             2020-04-12 09:41:35.096775
# TVAESynthesizer                 2020-04-12 09:41:35.096775
# UniformSynthesizer              2020-04-12 09:41:35.096775
# VEEGANSynthesizer               2020-04-12 09:41:35.096775
# KDECopulaNNPdf_RoundCategorical 2020-09-25 10:42:32.967643
#
#                                  intrusion/exec_time (s)  census/accuracy  \
# CLBNSynthesizer                                      NaN         0.895047
# CTGANSynthesizer                                     NaN         0.911337
# IdentitySynthesizer                                  NaN         0.907498
# IndependentSynthesizer                               NaN         0.680072
# MedganSynthesizer                                    NaN         0.813293
# TableganSynthesizer                                  NaN         0.935965
# TVAESynthesizer                                      NaN         0.924090
# UniformSynthesizer                                   NaN         0.442547
# VEEGANSynthesizer                                    NaN         0.764352
# KDECopulaNNPdf_RoundCategorical               584.073383         0.803650
#
#                                  census/f1                  timestamp  \
# CLBNSynthesizer                   0.273580 2020-04-12 09:41:35.096775
# CTGANSynthesizer                  0.375053 2020-04-12 09:41:35.096775
# IdentitySynthesizer               0.464470 2020-04-12 09:41:35.096775
# IndependentSynthesizer            0.056057 2020-04-12 09:41:35.096775
# MedganSynthesizer                 0.061012 2020-04-12 09:41:35.096775
# TableganSynthesizer               0.289943 2020-04-12 09:41:35.096775
# TVAESynthesizer                   0.406641 2020-04-12 09:41:35.096775
# UniformSynthesizer                0.097798 2020-04-12 09:41:35.096775
# VEEGANSynthesizer                 0.051816 2020-04-12 09:41:35.096775
# KDECopulaNNPdf_RoundCategorical   0.131464 2020-09-25 11:00:11.354934
#
#                                  census/exec_time (s)
# CLBNSynthesizer                                   NaN
# CTGANSynthesizer                                  NaN
# IdentitySynthesizer                               NaN
# IndependentSynthesizer                            NaN
# MedganSynthesizer                                 NaN
# TableganSynthesizer                               NaN
# TVAESynthesizer                                   NaN
# UniformSynthesizer                                NaN
# VEEGANSynthesizer                                 NaN
# KDECopulaNNPdf_RoundCategorical            254.091732

# %%
covtype_scores = benchmark(synthesizers=[KDECopulaNNPdf_RoundCategorical], datasets=['covtype'])
# Out:
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 53
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/metrics/classification.py:1436: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   precision = _prf_divide(tp_sum, pred_sum,
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 53
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/metrics/classification.py:1436: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   precision = _prf_divide(tp_sum, pred_sum,
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 53
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/metrics/classification.py:1436: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   precision = _prf_divide(tp_sum, pred_sum,

# %%
credit_scores = benchmark(synthesizers=[KDECopulaNNPdf_RoundCategorical], datasets=['credit'])
# Out:
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 29
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/metrics/classification.py:1436: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   precision = _prf_divide(tp_sum, pred_sum,
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 29
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/metrics/classification.py:1436: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   precision = _prf_divide(tp_sum, pred_sum,
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 29
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/metrics/classification.py:1436: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   precision = _prf_divide(tp_sum, pred_sum,
