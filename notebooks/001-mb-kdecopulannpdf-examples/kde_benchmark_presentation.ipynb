# %% [markdown]
# ### This notebook is used to perform gridsearch on asia dataset

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from sdgym import benchmark
from sdgym import load_dataset
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from synthsonic.models.kde_copula_nn_pdf import KDECopulaNNPdf
from synthsonic.models.categorical_utils import categorical_round, vec_translate, categorical_frequency_mapping, \
            categorical_frequency_inverse_mapping, encode_one_hot, decode_one_hot
from timeit import default_timer as timer
# %matplotlib inline

# %%
from functools import partial

# %% [markdown]
# ### Gaussian Mixtures datasets

# %%
def KDECopulaNNPdf_RoundCategorical(real_data, categorical_columns, ordinal_columns, times=None):
    # Max's kde copula model with default parameters
    start = timer()
    all_features = list(range(real_data.shape[1]))
    numerical_features = list(set(all_features) - set(categorical_columns + ordinal_columns))
    data = np.float64(real_data)
    
    n_samples = data.shape[0]
    n_features = data.shape[1]
    
    kde = KDECopulaNNPdf(use_KDE=False, clf=MLPClassifier(alpha=0.1, random_state=0, max_iter=1000, early_stopping=True))
    kde = kde.fit(data)
    
    X_gen, sample_weight = kde.sample(n_samples)
    
    X_gen[:, categorical_columns+ordinal_columns] = np.round(X_gen[:, categorical_columns+ordinal_columns])
    X_gen = np.float32(X_gen)
    end = timer()
    exec_time = end - start
    if isinstance(times, list):
        times.append(exec_time)
    return X_gen

# %%
grid_times = []
grid_thing = partial(KDECopulaNNPdf_RoundCategorical, times=grid_times)
grid_thing.__name__ = KDECopulaNNPdf_RoundCategorical.__name__
grid_scores = benchmark(synthesizers=[grid_thing], datasets=['grid'])
grid_scores.drop(columns=['timestamp'], inplace=True)
exec_time = ['N/A'] * 9 + [round(np.mean(grid_times), 2)]
grid_scores['grid/exec_time(s)'] = exec_time
# Out:
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 2
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 2
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 2

# %%
def KDECopulaNNPdf_RoundCategorical(real_data, categorical_columns, ordinal_columns, times=None):
    # Max's kde copula model with default parameters
    start = timer()
    all_features = list(range(real_data.shape[1]))
    numerical_features = list(set(all_features) - set(categorical_columns + ordinal_columns))
    data = np.float64(real_data)
    
    n_samples = data.shape[0]
    n_features = data.shape[1]
    
    kde = KDECopulaNNPdf(use_KDE=False, clf=XGBClassifier(n_estimators=50, reg_lambda=1, gamma=0, max_depth=2))
    kde = kde.fit(data)
    
    X_gen, sample_weight = kde.sample(n_samples)
    
    X_gen[:, categorical_columns+ordinal_columns] = np.round(X_gen[:, categorical_columns+ordinal_columns])
    X_gen = np.float32(X_gen)
    end = timer()
    exec_time = end - start
    if isinstance(times, list):
        times.append(exec_time)
    return X_gen

# %%
gridr_times = []
gridr_thing = partial(KDECopulaNNPdf_RoundCategorical, times=gridr_times)
gridr_thing.__name__ = KDECopulaNNPdf_RoundCategorical.__name__
gridr_scores = benchmark(synthesizers=[gridr_thing], datasets=['gridr'])
gridr_scores.drop(columns=['timestamp'], inplace=True)
exec_time = ['N/A'] * 9 + [round(np.mean(gridr_times), 2)]
gridr_scores['gridr/exec_time(s)'] = exec_time
# Out:
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 2
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 2
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 2

# %%
def KDECopulaNNPdf_RoundCategorical(real_data, categorical_columns, ordinal_columns, times=None):
    # Max's kde copula model with default parameters
    start = timer()
    all_features = list(range(real_data.shape[1]))
    numerical_features = list(set(all_features) - set(categorical_columns + ordinal_columns))
    data = np.float64(real_data)
    
    n_samples = data.shape[0]
    n_features = data.shape[1]
    
    kde = KDECopulaNNPdf(use_KDE=False, clf=XGBClassifier(n_estimators=50, reg_lambda=1, gamma=0, max_depth=2))
    kde = kde.fit(data)
    
    X_gen, sample_weight = kde.sample(n_samples)
    
    X_gen[:, categorical_columns+ordinal_columns] = np.round(X_gen[:, categorical_columns+ordinal_columns])
    X_gen = np.float32(X_gen)
    end = timer()
    exec_time = end - start
    if isinstance(times, list):
        times.append(exec_time)
    return X_gen

# %%
ring_times = []
ring_thing = partial(KDECopulaNNPdf_RoundCategorical, times=ring_times)
ring_thing.__name__ = KDECopulaNNPdf_RoundCategorical.__name__
ring_scores = benchmark(synthesizers=[ring_thing], datasets=['ring'])
ring_scores.drop(columns=['timestamp'], inplace=True)
exec_time = ['N/A'] * 9 + [round(np.mean(ring_times), 2)]
ring_scores['ring/exec_time(s)'] = exec_time
# Out:
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 2
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 2
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 2

# %%
gm_scores = pd.concat([grid_scores, gridr_scores, ring_scores], axis=1)
gm_scores
# Out:
#                                  grid/syn_likelihood  grid/test_likelihood  \
# CLBNSynthesizer                            -3.885928             -5.274841
# CTGANSynthesizer                           -9.162882             -5.066747
# IdentitySynthesizer                        -3.476662             -3.503242
# IndependentSynthesizer                     -3.544136             -3.469971
# MedganSynthesizer                          -6.833268            -84.380587
# TableganSynthesizer                        -6.777964             -4.931756
# TVAESynthesizer                            -3.388274             -5.190146
# UniformSynthesizer                         -7.294052             -4.534827
# VEEGANSynthesizer                          -8.646858           -423.573276
# KDECopulaNNPdf_RoundCategorical            -3.460550             -3.424869
#
#                                 grid/exec_time(s)  gridr/syn_likelihood  \
# CLBNSynthesizer                               N/A             -4.066210
# CTGANSynthesizer                              N/A             -8.653293
# IdentitySynthesizer                           N/A             -3.607534
# IndependentSynthesizer                        N/A             -5.033312
# MedganSynthesizer                             N/A             -7.747477
# TableganSynthesizer                           N/A             -7.080974
# TVAESynthesizer                               N/A             -3.820569
# UniformSynthesizer                            N/A             -7.227006
# VEEGANSynthesizer                             N/A            -11.458546
# KDECopulaNNPdf_RoundCategorical              2.65             -4.969674
#
#                                  gridr/test_likelihood gridr/exec_time(s)  \
# CLBNSynthesizer                             -10.287411                N/A
# CTGANSynthesizer                             -5.086304                N/A
# IdentitySynthesizer                          -3.635514                N/A
# IndependentSynthesizer                       -4.037670                N/A
# MedganSynthesizer                          -160.899159                N/A
# TableganSynthesizer                          -5.047245                N/A
# TVAESynthesizer                              -3.724633                N/A
# UniformSynthesizer                           -4.549560                N/A
# VEEGANSynthesizer                            -8.908475                N/A
# KDECopulaNNPdf_RoundCategorical              -3.971349               1.32
#
#                                  ring/syn_likelihood  ring/test_likelihood  \
# CLBNSynthesizer                            -1.750592            -18.904815
# CTGANSynthesizer                           -7.056122             -2.737149
# IdentitySynthesizer                        -1.713405             -1.704359
# IndependentSynthesizer                     -2.465557             -1.965117
# MedganSynthesizer                          -2.769543           -133.462900
# TableganSynthesizer                        -3.898531             -2.307308
# TVAESynthesizer                            -1.654247             -1.933056
# UniformSynthesizer                         -5.343589             -2.520734
# VEEGANSynthesizer                         -16.830634             -6.354960
# KDECopulaNNPdf_RoundCategorical            -1.992792             -1.825358
#
#                                 ring/exec_time(s)
# CLBNSynthesizer                               N/A
# CTGANSynthesizer                              N/A
# IdentitySynthesizer                           N/A
# IndependentSynthesizer                        N/A
# MedganSynthesizer                             N/A
# TableganSynthesizer                           N/A
# TVAESynthesizer                               N/A
# UniformSynthesizer                            N/A
# VEEGANSynthesizer                             N/A
# KDECopulaNNPdf_RoundCategorical              1.32

# %% [markdown]
# ### Bayesian Networks datasets

# %%
def KDECopulaNNPdf_RoundCategorical(real_data, categorical_columns, ordinal_columns, times=None):
    # Max's kde copula model with default parameters
    start = timer()
    all_features = list(range(real_data.shape[1]))
    numerical_features = list(set(all_features) - set(categorical_columns + ordinal_columns))
    data = np.float64(real_data)
    
    n_samples = data.shape[0]
    n_features = data.shape[1]
    
    kde = KDECopulaNNPdf(use_KDE=False, clf=MLPClassifier(hidden_layer_sizes=(100,), alpha=0.05, \
                                            max_iter=500, early_stopping=True, random_state=0))
    kde = kde.fit(data)
    
    X_gen, sample_weight = kde.sample(n_samples)
    
    X_gen[:, categorical_columns+ordinal_columns] = np.round(X_gen[:, categorical_columns+ordinal_columns])
    X_gen = np.float32(X_gen)
    end = timer()
    exec_time = end - start
    if isinstance(times, list):
        times.append(exec_time)
    return X_gen

# %%
asia_times = []
asia_thing = partial(KDECopulaNNPdf_RoundCategorical, times=asia_times)
asia_thing.__name__ = KDECopulaNNPdf_RoundCategorical.__name__
asia_scores = benchmark(synthesizers=[asia_thing], datasets=['asia'])
asia_scores.drop(columns=['timestamp'], inplace=True)
exec_time = ['N/A'] * 9 + [round(np.mean(asia_times), 2)]
asia_scores['asia/exec_time(s)'] = exec_time
# Out:
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 8
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 8
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 8

# %%
def KDECopulaNNPdf_RoundCategorical(real_data, categorical_columns, ordinal_columns, times=None):
    # Max's kde copula model with default parameters
    start = timer()
    all_features = list(range(real_data.shape[1]))
    numerical_features = list(set(all_features) - set(categorical_columns + ordinal_columns))
    data = np.float64(real_data)
    
    n_samples = data.shape[0]
    n_features = data.shape[1]
    
    kde = KDECopulaNNPdf(force_uncorrelated=True, use_KDE=False, clf=XGBClassifier(max_depth=3))
    kde = kde.fit(data)
    
    X_gen, sample_weight = kde.sample(n_samples)
    
    X_gen[:, categorical_columns+ordinal_columns] = np.round(X_gen[:, categorical_columns+ordinal_columns])
    X_gen = np.float32(X_gen)
    end = timer()
    exec_time = end - start
    if isinstance(times, list):
        times.append(exec_time)
    return X_gen

# %%
alarm_times = []
alarm_thing = partial(KDECopulaNNPdf_RoundCategorical, times=alarm_times)
alarm_thing.__name__ = KDECopulaNNPdf_RoundCategorical.__name__
alarm_scores = benchmark(synthesizers=[alarm_thing], datasets=['alarm'])
alarm_scores.drop(columns=['timestamp'], inplace=True)
exec_time = ['N/A'] * 9 + [round(np.mean(alarm_times), 2)]
alarm_scores['alarm/exec_time(s)'] = exec_time
# Out:
# Transforming variables.
# Model = rho: 0.5, number of selected non-linear variables: 0
# Transforming variables.
# Model = rho: 0.5, number of selected non-linear variables: 0
# Transforming variables.
# Model = rho: 0.5, number of selected non-linear variables: 0

# %%
# To do - was unable to do gridsearch for child and insurance datasets
def KDECopulaNNPdf_RoundCategorical(real_data, categorical_columns, ordinal_columns, times=None):
    # Max's kde copula model with default parameters
    start = timer()
    all_features = list(range(real_data.shape[1]))
    numerical_features = list(set(all_features) - set(categorical_columns + ordinal_columns))
    data = np.float64(real_data)
    
    n_samples = data.shape[0]
    n_features = data.shape[1]
    
    kde = KDECopulaNNPdf(use_KDE=False, clf=MLPClassifier(random_state=0, max_iter=500, early_stopping=True))
    kde = kde.fit(data)
    
    X_gen, sample_weight = kde.sample(n_samples)
    
    X_gen[:, categorical_columns+ordinal_columns] = np.round(X_gen[:, categorical_columns+ordinal_columns])
    X_gen = np.float32(X_gen)
    end = timer()
    exec_time = end - start
    if isinstance(times, list):
        times.append(exec_time)
    return X_gen

# %%
child_times = []
child_thing = partial(KDECopulaNNPdf_RoundCategorical, times=child_times)
child_thing.__name__ = KDECopulaNNPdf_RoundCategorical.__name__
child_scores = benchmark(synthesizers=[child_thing], datasets=['child'])
child_scores.drop(columns=['timestamp'], inplace=True)
exec_time = ['N/A'] * 9 + [round(np.mean(child_times), 2)]
child_scores['child/exec_time(s)'] = exec_time
# Out:
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 20
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 20
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 20

# %%
insurance_times = []
insurance_thing = partial(KDECopulaNNPdf_RoundCategorical, times=insurance_times)
insurance_thing.__name__ = KDECopulaNNPdf_RoundCategorical.__name__
insurance_scores = benchmark(synthesizers=[insurance_thing], datasets=['insurance'])
insurance_scores.drop(columns=['timestamp'], inplace=True)
exec_time = ['N/A'] * 9 + [round(np.mean(insurance_times), 2)]
insurance_scores['insurance/exec_time(s)'] = exec_time
# Out:
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 27
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 27
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 27

# %%
bn_scores = pd.concat([asia_scores, alarm_scores, child_scores, insurance_scores], axis=1)
bn_scores
#bn_scores.loc[:, ~bn_scores.columns.str.endswith('syn_likelihood')]
# Out:
#                                  asia/syn_likelihood  asia/test_likelihood  \
# CLBNSynthesizer                            -2.406589             -2.271840
# CTGANSynthesizer                           -3.886903             -2.442375
# IdentitySynthesizer                        -2.250748             -2.241122
# IndependentSynthesizer                     -4.933314             -3.001627
# MedganSynthesizer                          -1.519422             -5.197981
# TableganSynthesizer                        -3.331052             -2.684490
# TVAESynthesizer                            -2.353327             -2.267334
# UniformSynthesizer                        -14.301042             -5.551594
# VEEGANSynthesizer                         -11.492287             -5.952712
# KDECopulaNNPdf_RoundCategorical            -4.427508             -2.620132
#
#                                 asia/exec_time(s)  alarm/syn_likelihood  \
# CLBNSynthesizer                               N/A            -12.385436
# CTGANSynthesizer                              N/A            -15.625477
# IdentitySynthesizer                           N/A            -10.233935
# IndependentSynthesizer                        N/A            -18.230315
# MedganSynthesizer                             N/A             -8.169461
# TableganSynthesizer                           N/A            -12.744195
# TVAESynthesizer                               N/A            -11.357112
# UniformSynthesizer                            N/A            -18.420681
# VEEGANSynthesizer                             N/A            -18.386073
# KDECopulaNNPdf_RoundCategorical              8.39            -18.232053
#
#                                  alarm/test_likelihood alarm/exec_time(s)  \
# CLBNSynthesizer                             -11.181650                N/A
# CTGANSynthesizer                            -12.915224                N/A
# IdentitySynthesizer                         -10.301955                N/A
# IndependentSynthesizer                      -15.805230                N/A
# MedganSynthesizer                           -13.020430                N/A
# TableganSynthesizer                         -11.565230                N/A
# TVAESynthesizer                             -10.754935                N/A
# UniformSynthesizer                          -18.420681                N/A
# VEEGANSynthesizer                           -18.210907                N/A
# KDECopulaNNPdf_RoundCategorical             -15.818839               0.95
#
#                                  child/syn_likelihood  child/test_likelihood  \
# CLBNSynthesizer                            -12.636520             -12.307927
# CTGANSynthesizer                           -14.044374             -12.832626
# IdentitySynthesizer                        -12.045682             -12.041519
# IndependentSynthesizer                     -17.949428             -16.045038
# MedganSynthesizer                          -11.198930             -13.099122
# TableganSynthesizer                        -14.768575             -13.241063
# TVAESynthesizer                            -12.285050             -12.248007
# UniformSynthesizer                         -18.409743             -18.333704
# VEEGANSynthesizer                          -17.314284             -17.681452
# KDECopulaNNPdf_RoundCategorical            -17.320326             -14.822142
#
#                                 child/exec_time(s)  insurance/syn_likelihood  \
# CLBNSynthesizer                                N/A                -15.206133
# CTGANSynthesizer                               N/A                -16.917861
# IdentitySynthesizer                            N/A                -12.850257
# IndependentSynthesizer                         N/A                -18.381496
# MedganSynthesizer                              N/A                -13.801601
# TableganSynthesizer                            N/A                -16.087381
# TVAESynthesizer                                N/A                -14.293042
# UniformSynthesizer                             N/A                -18.420681
# VEEGANSynthesizer                              N/A                -18.325827
# KDECopulaNNPdf_RoundCategorical               15.5                -18.061324
#
#                                  insurance/test_likelihood  \
# CLBNSynthesizer                                 -13.917471
# CTGANSynthesizer                                -14.961379
# IdentitySynthesizer                             -12.959072
# IndependentSynthesizer                          -17.563807
# MedganSynthesizer                               -14.943327
# TableganSynthesizer                             -14.299552
# TVAESynthesizer                                 -13.823180
# UniformSynthesizer                              -18.420677
# VEEGANSynthesizer                               -18.113419
# KDECopulaNNPdf_RoundCategorical                 -16.218595
#
#                                 insurance/exec_time(s)
# CLBNSynthesizer                                    N/A
# CTGANSynthesizer                                   N/A
# IdentitySynthesizer                                N/A
# IndependentSynthesizer                             N/A
# MedganSynthesizer                                  N/A
# TableganSynthesizer                                N/A
# TVAESynthesizer                                    N/A
# UniformSynthesizer                                 N/A
# VEEGANSynthesizer                                  N/A
# KDECopulaNNPdf_RoundCategorical                   19.8

# %% [markdown]
# ### Real world datasets

# %%
def KDECopulaNNPdf_RoundCategorical(real_data, categorical_columns, ordinal_columns, times=None):
    # Max's kde copula model with default parameters
    start = timer()
    all_features = list(range(real_data.shape[1]))
    numerical_features = list(set(all_features) - set(categorical_columns + ordinal_columns))
    data = np.float64(real_data)
    
    n_samples = data.shape[0]
    n_features = data.shape[1]
    
    kde = KDECopulaNNPdf(use_KDE=False, clf=XGBClassifier(random_state=0, n_estimators=100, reg_lambda=1, gamma=0, max_depth=3))
    kde = kde.fit(data)
    
    X_gen, sample_weight = kde.sample(n_samples)
    
    X_gen[:, categorical_columns+ordinal_columns] = np.round(X_gen[:, categorical_columns+ordinal_columns])
    X_gen = np.float32(X_gen)
    end = timer()
    exec_time = end - start
    if isinstance(times, list):
        times.append(exec_time)
    return X_gen

# %%
adult_times = []
adult_thing = partial(KDECopulaNNPdf_RoundCategorical, times=adult_times)
adult_thing.__name__ = KDECopulaNNPdf_RoundCategorical.__name__
adult_scores = benchmark(synthesizers=[adult_thing], datasets=['adult'])
adult_scores.drop(columns=['timestamp'], inplace=True)
exec_time = ['N/A'] * 9 + [round(np.mean(adult_times), 2)]
adult_scores['adult/exec_time(s)'] = exec_time
# Out:
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 14
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 14
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 14
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
def KDECopulaNNPdf_RoundCategorical(real_data, categorical_columns, ordinal_columns, times=None):
    # Max's kde copula model with default parameters
    start = timer()
    all_features = list(range(real_data.shape[1]))
    numerical_features = list(set(all_features) - set(categorical_columns + ordinal_columns))
    data = np.float64(real_data)
    
    n_samples = data.shape[0]
    n_features = data.shape[1]
    
    kde = KDECopulaNNPdf(force_uncorrelated=False, use_KDE=False, n_nonlinear_vars=36, clf=XGBClassifier(max_depth=3, n_estimators=250))
    kde = kde.fit(data)
    
    X_gen, sample_weight = kde.sample(n_samples)
    
    X_gen[:, categorical_columns+ordinal_columns] = np.round(X_gen[:, categorical_columns+ordinal_columns])
    X_gen = np.float32(X_gen)
    end = timer()
    exec_time = end - start
    if isinstance(times, list):
        times.append(exec_time)
    return X_gen

# %%
intrusion_times = []
intrusion_thing = partial(KDECopulaNNPdf_RoundCategorical, times=intrusion_times)
intrusion_thing.__name__ = KDECopulaNNPdf_RoundCategorical.__name__
intrusion_scores = benchmark(synthesizers=[intrusion_thing], datasets=['intrusion'])
intrusion_scores.drop(columns=['timestamp'], inplace=True)
exec_time = ['N/A'] * 9 + [round(np.mean(intrusion_times), 2)]
intrusion_scores['intrusion/exec_time(s)'] = exec_time
# Out:
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 36
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sdgym/evaluate.py:112: RuntimeWarning: overflow encountered in log
#   feature = np.log(np.maximum(col, 1e-2))
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 36
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sdgym/evaluate.py:112: RuntimeWarning: overflow encountered in log
#   feature = np.log(np.maximum(col, 1e-2))
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 36
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sdgym/evaluate.py:112: RuntimeWarning: overflow encountered in log
#   feature = np.log(np.maximum(col, 1e-2))
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
def KDECopulaNNPdf_RoundCategorical(real_data, categorical_columns, ordinal_columns, times=None):
    # Max's kde copula model with default parameters
    start = timer()
    all_features = list(range(real_data.shape[1]))
    numerical_features = list(set(all_features) - set(categorical_columns + ordinal_columns))
    data = np.float64(real_data)
    
    n_samples = data.shape[0]
    n_features = data.shape[1]
    
    kde = KDECopulaNNPdf(use_KDE=False, clf=MLPClassifier(random_state=0, max_iter=500, early_stopping=True))
    kde = kde.fit(data)
    
    X_gen, sample_weight = kde.sample(n_samples)
    
    X_gen[:, categorical_columns+ordinal_columns] = np.round(X_gen[:, categorical_columns+ordinal_columns])
    X_gen = np.float32(X_gen)
    end = timer()
    exec_time = end - start
    if isinstance(times, list):
        times.append(exec_time)
    return X_gen

# %%
census_times = []
census_thing = partial(KDECopulaNNPdf_RoundCategorical, times=census_times)
census_thing.__name__ = KDECopulaNNPdf_RoundCategorical.__name__
census_scores = benchmark(synthesizers=[census_thing], datasets=['census'])
census_scores.drop(columns=['timestamp'], inplace=True)
exec_time = ['N/A'] * 9 + [round(np.mean(census_times), 2)]
census_scores['intrusion/exec_time(s)'] = exec_time
# Out:
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 35
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 35
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Transforming variables.
# Fitting and calibrating classifier.
# Model = rho: 0.5, number of selected non-linear variables: 35
# /Users/lorrainedalmeida/Work/Experiment_Week/synthsonic/env/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
rw_scores = pd.concat([adult_scores, intrusion_scores, census_scores], axis=1)
rw_scores
# Out:
#                                  adult/accuracy  adult/f1 adult/exec_time(s)  \
# CLBNSynthesizer                        0.760117  0.291326                N/A
# CTGANSynthesizer                       0.784217  0.597420                N/A
# IdentitySynthesizer                    0.825608  0.661600                N/A
# IndependentSynthesizer                 0.654425  0.174515                N/A
# MedganSynthesizer                      0.593683  0.276167                N/A
# TableganSynthesizer                    0.798850  0.426258                N/A
# TVAESynthesizer                        0.810817  0.630175                N/A
# UniformSynthesizer                     0.500242  0.301878                N/A
# VEEGANSynthesizer                      0.718792  0.162142                N/A
# KDECopulaNNPdf_RoundCategorical        0.746300  0.398891              12.46
#
#                                  intrusion/accuracy  intrusion/macro_f1  \
# CLBNSynthesizer                            0.887753            0.343114
# CTGANSynthesizer                           0.973317            0.483286
# IdentitySynthesizer                        0.999083            0.867048
# IndependentSynthesizer                     0.554480            0.148850
# MedganSynthesizer                          0.759467            0.270662
# TableganSynthesizer                             NaN                 NaN
# TVAESynthesizer                            0.977433            0.461439
# UniformSynthesizer                         0.103120            0.080952
# VEEGANSynthesizer                          0.506413            0.180797
# KDECopulaNNPdf_RoundCategorical            0.928900            0.365089
#
#                                  intrusion/micro_f1 intrusion/exec_time(s)  \
# CLBNSynthesizer                            0.887753                    N/A
# CTGANSynthesizer                           0.973317                    N/A
# IdentitySynthesizer                        0.999083                    N/A
# IndependentSynthesizer                     0.554480                    N/A
# MedganSynthesizer                          0.759467                    N/A
# TableganSynthesizer                             NaN                    N/A
# TVAESynthesizer                            0.977433                    N/A
# UniformSynthesizer                         0.103120                    N/A
# VEEGANSynthesizer                          0.506413                    N/A
# KDECopulaNNPdf_RoundCategorical            0.928900                 889.04
#
#                                  census/accuracy  census/f1  \
# CLBNSynthesizer                         0.895047   0.273580
# CTGANSynthesizer                        0.911337   0.375053
# IdentitySynthesizer                     0.907498   0.464470
# IndependentSynthesizer                  0.680072   0.056057
# MedganSynthesizer                       0.813293   0.061012
# TableganSynthesizer                     0.935965   0.289943
# TVAESynthesizer                         0.924090   0.406641
# UniformSynthesizer                      0.442547   0.097798
# VEEGANSynthesizer                       0.764352   0.051816
# KDECopulaNNPdf_RoundCategorical         0.780665   0.118767
#
#                                 intrusion/exec_time(s)
# CLBNSynthesizer                                    N/A
# CTGANSynthesizer                                   N/A
# IdentitySynthesizer                                N/A
# IndependentSynthesizer                             N/A
# MedganSynthesizer                                  N/A
# TableganSynthesizer                                N/A
# TVAESynthesizer                                    N/A
# UniformSynthesizer                                 N/A
# VEEGANSynthesizer                                  N/A
# KDECopulaNNPdf_RoundCategorical                 397.82
